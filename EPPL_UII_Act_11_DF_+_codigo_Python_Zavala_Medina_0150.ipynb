# %% [markdown]
# <a href="https://colab.research.google.com/github/zavalaalexia128/EPPL-Area-un-triangulo-mis-imagenes/blob/main/EPPL_UII_Act_11_DF_%2B_codigo_Python_Zavala_Medina_0150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Zavala Medina Fecha 25/Mar/2026
# ---
# # Calcular Area  de triangulo
# ---
# ![Logo de markdown](https://raw.githubusercontent.com/zavalaalexia128/EPPL-Area-un-triangulo-mis-imagenes/refs/heads/main/trianguloimagen.PNG)
#
# ---
# ## Formula para calcular el area
# $A=b*h/2$
# ---
# ## Diagrama de flujo en LucidChart
# ![DF](https://raw.githubusercontent.com/zavalaalexia128/EPPL-Area-un-triangulo-mis-imagenes/refs/heads/main/Diagrama%20en%20blanco.png)

# %%
# Calculando area de triangulo
# Variables a, b, h
# Formula A = B * H/2
# Captura el area
import math
b = float(input("Ingrese la base del triangulo: "))
h = float(input("Ingrese la altura del triangulo: "))
a = b * h/2
print("El area del triangulo es: ",a)
print("Programa realizado por Zavala Medina NL = 54")
# Out:
# Ingrese la altura del triangulo: 15
# Ingrese la base del triangulo: 11
# El area del triangulo es:  82.5
# Programa realizado por Zavala Medina NL = 54

# %% [markdown]
# ## Similitudes de codigo y DF
# ![Similitudes](https://raw.githubusercontent.com/zavalaalexia128/EPPL-Area-un-triangulo-mis-imagenes/refs/heads/main/SIMILITUDES%20DE%20CODIGO%20Y%20DF.PNG)
